# %%
# !pip install gtts
# Out:
# Collecting gtts
#   Downloading gTTS-2.5.4-py3-none-any.whl.metadata (4.1 kB)
# Requirement already satisfied: requests<3,>=2.27 in /home/susan/miniconda3/envs/ds/lib/python3.10/site-packages (from gtts) (2.32.5)
# Collecting click<8.2,>=7.1 (from gtts)
#   Using cached click-8.1.8-py3-none-any.whl.metadata (2.3 kB)
# Requirement already satisfied: charset_normalizer<4,>=2 in /home/susan/miniconda3/envs/ds/lib/python3.10/site-packages (from requests<3,>=2.27->gtts) (3.4.4)
# Requirement already satisfied: idna<4,>=2.5 in /home/susan/miniconda3/envs/ds/lib/python3.10/site-packages (from requests<3,>=2.27->gtts) (3.11)
# Requirement already satisfied: urllib3<3,>=1.21.1 in /home/susan/miniconda3/envs/ds/lib/python3.10/site-packages (from requests<3,>=2.27->gtts) (2.6.1)
# Requirement already satisfied: certifi>=2017.4.17 in /home/susan/miniconda3/envs/ds/lib/python3.10/site-packages (from requests<3,>=2.27->gtts) (2026.1.4)
# Downloading gTTS-2.5.4-py3-none-any.whl (29 kB)
# Using cached click-8.1.8-py3-none-any.whl (98 kB)
# Installing collected packages: click, gtts
#   Attempting uninstall: click
#     Found existing installation: click 8.4.2
#     Uninstalling click-8.4.2:
#       Successfully uninstalled click-8.4.2
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 2/2 [gtts]
# ERROR: pip's dependency resolver does not currently take into account all the packages that are installed. This behaviour is the source of the following dependency conflicts.
# huggingface-hub 1.26.0 requires click<9.0.0,>=8.4.2, but you have click 8.1.8 which is incompatible.
# Successfully installed click-8.1.8 gtts-2.5.4

# %%
from gtts import gTTS
import os

# %%
text = "तपाईंको नाम के हो?"

# %%
tts = gTTS(text=text, lang='ne')

# %%
tts.save("nepali_speech.mp3")

# %%
from IPython.display import Audio

# %%
Audio("nepali_speech.mp3", autoplay=True)
# Out:
#                 <audio  controls="controls" autoplay="autoplay">
#                     <source src="data:audio/mpeg;base64,..." type="audio/mpeg" />
#                     Your browser does not support the audio element.
#                 </audio>
